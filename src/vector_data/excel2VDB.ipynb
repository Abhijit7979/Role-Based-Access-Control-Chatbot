# %%
from rich import print
import os
from dotenv import load_dotenv
load_dotenv("../../.env")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma
model=OpenAIEmbeddings(model="text-embedding-3-large")
# Out:
# /var/folders/dd/ffn14k7x4bz7kmmd0l7kmqg80000gn/T/ipykernel_12183/1201455480.py:4: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   model=OpenAIEmbeddings(model="text-embedding-3-large")

# %%
loader=CSVLoader(file_path="../../data/hr/hr_data.csv")

# %%
data=loader.load()

# %%
print(data)
# Out:
# [
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 0},
#         page_content='employee_id: FINEMP1000\nfull_name: Aadhya Patel\nrole: Sales Manager\ndepartment:
# Sales\nemail: aadhya.patel@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1991-04-03\ndate_of_joining:
# 2018-11-20\nmanager_id: FINEMP1006\nsalary: 1332478.37\nleave_balance: 22\nleaves_taken: 11\nattendance_pct:
# 99.31\nperformance_rating: 3\nlast_review_date: 2024-05-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 1},
#         page_content='employee_id: FINEMP1001\nfull_name: Isha Chowdhury\nrole: Credit Officer\ndepartment:
# Finance\nemail: isha.chowdhury@fintechco.com\nlocation: Pune\ndate_of_birth: 1995-09-21\ndate_of_joining:
# 2021-05-20\nmanager_id: FINEMP1005\nsalary: 1491158.23\nleave_balance: 8\nleaves_taken: 3\nattendance_pct:
# 85.15\nperformance_rating: 5\nlast_review_date: 2024-01-20'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 2},
#         page_content='employee_id: FINEMP1002\nfull_name: Sakshi Malhotra\nrole: Relationship Manager\ndepartment:
# Sales\nemail: sakshi.malhotra@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1993-08-05\ndate_of_joining:
# 2023-04-17\nmanager_id: FINEMP1008\nsalary: 1448927.95\nleave_balance: 21\nleaves_taken: 7\nattendance_pct:
# 86.31\nperformance_rating: 2\nlast_review_date: 2025-02-11'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 3},
#         page_content='employee_id: FINEMP1003\nfull_name: Krishna Malhotra\nrole: Business Analyst\ndepartment:
# Business\nemail: krishna.malhotra@fintechco.com\nlocation: Pune\ndate_of_birth: 1984-12-20\ndate_of_joining:
# 2018-06-10\nmanager_id: FINEMP1003\nsalary: 519865.26\nleave_balance: 12\nleaves_taken: 5\nattendance_pct:
# 84.34\nperformance_rating: 1\nlast_review_date: 2024-07-24'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 4},
#         page_content='employee_id: FINEMP1004\nfull_name: Aadhya Saxena\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: aadhya.saxena@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1986-03-31\ndate_of_joining:
# 2022-12-20\nmanager_id: FINEMP1008\nsalary: 1922205.04\nleave_balance: 21\nleaves_taken: 10\nattendance_pct:
# 86.03\nperformance_rating: 3\nlast_review_date: 2024-01-12'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 5},
#         page_content='employee_id: FINEMP1005\nfull_name: Shaurya Joshi\nrole: Financial Analyst\ndepartment:
# Finance\nemail: shaurya.joshi@fintechco.com\nlocation: Delhi\ndate_of_birth: 1977-05-28\ndate_of_joining:
# 2020-10-31\nmanager_id: FINEMP1009\nsalary: 1085205.18\nleave_balance: 4\nleaves_taken: 4\nattendance_pct:
# 82.77\nperformance_rating: 2\nlast_review_date: 2024-09-15'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 6},
#         page_content='employee_id: FINEMP1006\nfull_name: Sara Sharma\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: sara.sharma@fintechco.com\nlocation: Delhi\ndate_of_birth: 1989-12-26\ndate_of_joining:
# 2021-05-15\nmanager_id: FINEMP1004\nsalary: 660681.91\nleave_balance: 11\nleaves_taken: 10\nattendance_pct:
# 96.49\nperformance_rating: 2\nlast_review_date: 2024-02-26'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 7},
#         page_content='employee_id: FINEMP1007\nfull_name: Prisha Mehta\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: prisha.mehta@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1976-11-01\ndate_of_joining:
# 2020-11-30\nmanager_id: FINEMP1000\nsalary: 1149019.58\nleave_balance: 11\nleaves_taken: 10\nattendance_pct:
# 82.97\nperformance_rating: 4\nlast_review_date: 2024-01-31'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 8},
#         page_content='employee_id: FINEMP1008\nfull_name: Aadhya Chowdhury\nrole: Customer Support\ndepartment:
# Operations\nemail: aadhya.chowdhury@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1977-06-18\ndate_of_joining:
# 2019-02-12\nmanager_id: FINEMP1007\nsalary: 370315.98\nleave_balance: 7\nleaves_taken: 5\nattendance_pct:
# 96.92\nperformance_rating: 5\nlast_review_date: 2024-08-07'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 9},
#         page_content='employee_id: FINEMP1009\nfull_name: Sai Gupta\nrole: Credit Officer\ndepartment:
# Finance\nemail: sai.gupta@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1976-09-21\ndate_of_joining:
# 2021-10-13\nmanager_id: FINEMP1009\nsalary: 309717.04\nleave_balance: 10\nleaves_taken: 4\nattendance_pct:
# 90.29\nperformance_rating: 2\nlast_review_date: 2025-04-22'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 10},
#         page_content='employee_id: FINEMP1010\nfull_name: Vihaan Chowdhury\nrole: HR Manager\ndepartment:
# HR\nemail: vihaan.chowdhury@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1996-12-31\ndate_of_joining:
# 2021-10-23\nmanager_id: FINEMP1007\nsalary: 1201969.11\nleave_balance: 10\nleaves_taken: 2\nattendance_pct:
# 99.98\nperformance_rating: 5\nlast_review_date: 2024-04-20'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 11},
#         page_content='employee_id: FINEMP1011\nfull_name: Sai Sharma\nrole: Business Analyst\ndepartment:
# Business\nemail: sai.sharma@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1975-03-02\ndate_of_joining:
# 2021-05-21\nmanager_id: FINEMP1004\nsalary: 1129637.9\nleave_balance: 24\nleaves_taken: 7\nattendance_pct:
# 97.41\nperformance_rating: 5\nlast_review_date: 2024-01-07'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 12},
#         page_content='employee_id: FINEMP1012\nfull_name: Ishaan Patel\nrole: Security Engineer\ndepartment:
# Technology\nemail: ishaan.patel@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1977-08-20\ndate_of_joining:
# 2021-03-14\nmanager_id: FINEMP1007\nsalary: 1703783.22\nleave_balance: 13\nleaves_taken: 1\nattendance_pct:
# 97.57\nperformance_rating: 3\nlast_review_date: 2024-11-28'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 13},
#         page_content='employee_id: FINEMP1013\nfull_name: Prisha Banerjee\nrole: Security Engineer\ndepartment:
# Technology\nemail: prisha.banerjee@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1982-02-25\ndate_of_joining:
# 2020-04-12\nmanager_id: FINEMP1009\nsalary: 759800.28\nleave_balance: 8\nleaves_taken: 2\nattendance_pct:
# 99.38\nperformance_rating: 1\nlast_review_date: 2024-11-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 14},
#         page_content='employee_id: FINEMP1014\nfull_name: Isha Desai\nrole: Treasury Analyst\ndepartment:
# Finance\nemail: isha.desai@fintechco.com\nlocation: Chennai\ndate_of_birth: 1983-11-05\ndate_of_joining:
# 2023-03-25\nmanager_id: FINEMP1002\nsalary: 467884.86\nleave_balance: 17\nleaves_taken: 8\nattendance_pct:
# 87.03\nperformance_rating: 3\nlast_review_date: 2024-06-18'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 15},
#         page_content='employee_id: FINEMP1015\nfull_name: Ananya Singh\nrole: HR Manager\ndepartment: HR\nemail:
# ananya.singh@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1994-07-14\ndate_of_joining:
# 2018-08-17\nmanager_id: FINEMP1001\nsalary: 1074426.0\nleave_balance: 1\nleaves_taken: 0\nattendance_pct:
# 86.84\nperformance_rating: 4\nlast_review_date: 2024-07-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 16},
#         page_content='employee_id: FINEMP1016\nfull_name: Ananya Reddy\nrole: Relationship Manager\ndepartment:
# Sales\nemail: ananya.reddy@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1980-10-27\ndate_of_joining:
# 2020-07-10\nmanager_id: FINEMP1003\nsalary: 1876390.13\nleave_balance: 28\nleaves_taken: 5\nattendance_pct:
# 85.52\nperformance_rating: 5\nlast_review_date: 2025-03-16'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 17},
#         page_content='employee_id: FINEMP1017\nfull_name: Prisha Saxena\nrole: DevOps Engineer\ndepartment:
# Technology\nemail: prisha.saxena@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1977-05-17\ndate_of_joining:
# 2019-10-20\nmanager_id: FINEMP1004\nsalary: 526736.68\nleave_balance: 20\nleaves_taken: 6\nattendance_pct:
# 88.24\nperformance_rating: 1\nlast_review_date: 2025-04-10'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 18},
#         page_content='employee_id: FINEMP1018\nfull_name: Vivaan Reddy\nrole: Compliance Officer\ndepartment:
# Compliance\nemail: vivaan.reddy@fintechco.com\nlocation: Chennai\ndate_of_birth: 1975-11-20\ndate_of_joining:
# 2024-11-17\nmanager_id: FINEMP1001\nsalary: 480639.52\nleave_balance: 29\nleaves_taken: 17\nattendance_pct:
# 89.53\nperformance_rating: 5\nlast_review_date: 2024-05-09'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 19},
#         page_content='employee_id: FINEMP1019\nfull_name: Isha Chowdhury\nrole: Relationship Manager\ndepartment:
# Sales\nemail: isha.chowdhury@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1985-08-21\ndate_of_joining:
# 2019-03-06\nmanager_id: FINEMP1000\nsalary: 443210.71\nleave_balance: 11\nleaves_taken: 3\nattendance_pct:
# 87.92\nperformance_rating: 5\nlast_review_date: 2024-12-20'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 20},
#         page_content='employee_id: FINEMP1020\nfull_name: Krishna Verma\nrole: Sales Manager\ndepartment:
# Sales\nemail: krishna.verma@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1978-06-25\ndate_of_joining:
# 2024-11-29\nmanager_id: FINEMP1007\nsalary: 969422.69\nleave_balance: 24\nleaves_taken: 13\nattendance_pct:
# 94.35\nperformance_rating: 1\nlast_review_date: 2024-09-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 21},
#         page_content='employee_id: FINEMP1021\nfull_name: Vihaan Verma\nrole: Treasury Analyst\ndepartment:
# Finance\nemail: vihaan.verma@fintechco.com\nlocation: Delhi\ndate_of_birth: 1976-07-27\ndate_of_joining:
# 2022-05-29\nmanager_id: FINEMP1006\nsalary: 1940128.43\nleave_balance: 23\nleaves_taken: 4\nattendance_pct:
# 83.76\nperformance_rating: 1\nlast_review_date: 2025-03-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 22},
#         page_content='employee_id: FINEMP1022\nfull_name: Sai Khan\nrole: Customer Support\ndepartment:
# Operations\nemail: sai.khan@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1988-06-03\ndate_of_joining:
# 2023-09-07\nmanager_id: FINEMP1005\nsalary: 1392523.21\nleave_balance: 9\nleaves_taken: 4\nattendance_pct:
# 81.41\nperformance_rating: 1\nlast_review_date: 2025-03-31'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 23},
#         page_content='employee_id: FINEMP1023\nfull_name: Krishna Gupta\nrole: Business Analyst\ndepartment:
# Business\nemail: krishna.gupta@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1992-03-23\ndate_of_joining:
# 2024-05-06\nmanager_id: FINEMP1004\nsalary: 1154429.09\nleave_balance: 16\nleaves_taken: 7\nattendance_pct:
# 80.64\nperformance_rating: 2\nlast_review_date: 2024-01-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 24},
#         page_content='employee_id: FINEMP1024\nfull_name: Reyansh Mehta\nrole: Security Engineer\ndepartment:
# Technology\nemail: reyansh.mehta@fintechco.com\nlocation: Delhi\ndate_of_birth: 1994-12-19\ndate_of_joining:
# 2023-03-23\nmanager_id: FINEMP1001\nsalary: 611560.84\nleave_balance: 29\nleaves_taken: 8\nattendance_pct:
# 91.43\nperformance_rating: 2\nlast_review_date: 2025-01-17'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 25},
#         page_content='employee_id: FINEMP1025\nfull_name: Krishna Reddy\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: krishna.reddy@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1999-06-08\ndate_of_joining:
# 2021-06-12\nmanager_id: FINEMP1004\nsalary: 340969.05\nleave_balance: 18\nleaves_taken: 4\nattendance_pct:
# 84.73\nperformance_rating: 3\nlast_review_date: 2024-04-05'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 26},
#         page_content='employee_id: FINEMP1026\nfull_name: Ishaan Patel\nrole: Blockchain Developer\ndepartment:
# Technology\nemail: ishaan.patel@fintechco.com\nlocation: Delhi\ndate_of_birth: 1983-12-04\ndate_of_joining:
# 2024-08-25\nmanager_id: FINEMP1007\nsalary: 1836299.49\nleave_balance: 14\nleaves_taken: 13\nattendance_pct:
# 86.13\nperformance_rating: 1\nlast_review_date: 2024-12-12'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 27},
#         page_content='employee_id: FINEMP1027\nfull_name: Myra Desai\nrole: Security Engineer\ndepartment:
# Technology\nemail: myra.desai@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1978-10-20\ndate_of_joining:
# 2019-02-25\nmanager_id: FINEMP1009\nsalary: 1710679.64\nleave_balance: 4\nleaves_taken: 2\nattendance_pct:
# 96.01\nperformance_rating: 1\nlast_review_date: 2024-06-08'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 28},
#         page_content='employee_id: FINEMP1028\nfull_name: Isha Nair\nrole: Compliance Officer\ndepartment:
# Compliance\nemail: isha.nair@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1983-11-14\ndate_of_joining:
# 2024-06-04\nmanager_id: FINEMP1007\nsalary: 1343177.54\nleave_balance: 20\nleaves_taken: 6\nattendance_pct:
# 96.85\nperformance_rating: 4\nlast_review_date: 2025-03-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 29},
#         page_content='employee_id: FINEMP1029\nfull_name: Aditya Patel\nrole: Data Analyst\ndepartment:
# Data\nemail: aditya.patel@fintechco.com\nlocation: Pune\ndate_of_birth: 1997-06-28\ndate_of_joining:
# 2020-01-17\nmanager_id: FINEMP1009\nsalary: 1128053.06\nleave_balance: 23\nleaves_taken: 11\nattendance_pct:
# 97.48\nperformance_rating: 2\nlast_review_date: 2025-02-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 30},
#         page_content='employee_id: FINEMP1030\nfull_name: Vihaan Reddy\nrole: Data Scientist\ndepartment:
# Data\nemail: vihaan.reddy@fintechco.com\nlocation: Chennai\ndate_of_birth: 1984-01-30\ndate_of_joining:
# 2020-04-27\nmanager_id: FINEMP1003\nsalary: 436056.24\nleave_balance: 25\nleaves_taken: 13\nattendance_pct:
# 90.6\nperformance_rating: 5\nlast_review_date: 2024-02-07'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 31},
#         page_content='employee_id: FINEMP1031\nfull_name: Isha Desai\nrole: Compliance Officer\ndepartment:
# Compliance\nemail: isha.desai@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1996-06-26\ndate_of_joining:
# 2023-12-16\nmanager_id: FINEMP1009\nsalary: 1363418.93\nleave_balance: 6\nleaves_taken: 6\nattendance_pct:
# 84.54\nperformance_rating: 5\nlast_review_date: 2024-12-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 32},
#         page_content='employee_id: FINEMP1032\nfull_name: Arjun Desai\nrole: Financial Analyst\ndepartment:
# Finance\nemail: arjun.desai@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1985-01-29\ndate_of_joining:
# 2024-10-21\nmanager_id: FINEMP1009\nsalary: 1069322.39\nleave_balance: 29\nleaves_taken: 24\nattendance_pct:
# 96.83\nperformance_rating: 1\nlast_review_date: 2024-01-20'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 33},
#         page_content='employee_id: FINEMP1033\nfull_name: Saanvi Bhat\nrole: Risk Analyst\ndepartment: Risk\nemail:
# saanvi.bhat@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1985-10-07\ndate_of_joining: 2022-06-26\nmanager_id:
# FINEMP1003\nsalary: 1513021.23\nleave_balance: 8\nleaves_taken: 2\nattendance_pct: 97.62\nperformance_rating:
# 1\nlast_review_date: 2024-10-09'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 34},
#         page_content='employee_id: FINEMP1034\nfull_name: Diya Desai\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: diya.desai@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1980-09-05\ndate_of_joining:
# 2023-01-09\nmanager_id: FINEMP1002\nsalary: 1243560.93\nleave_balance: 26\nleaves_taken: 4\nattendance_pct:
# 97.76\nperformance_rating: 2\nlast_review_date: 2024-09-08'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 35},
#         page_content='employee_id: FINEMP1035\nfull_name: Arjun Chopra\nrole: Treasury Analyst\ndepartment:
# Finance\nemail: arjun.chopra@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1991-04-25\ndate_of_joining:
# 2019-02-20\nmanager_id: FINEMP1005\nsalary: 1507283.59\nleave_balance: 21\nleaves_taken: 11\nattendance_pct:
# 80.39\nperformance_rating: 3\nlast_review_date: 2025-04-04'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 36},
#         page_content='employee_id: FINEMP1036\nfull_name: Avni Khan\nrole: Business Analyst\ndepartment:
# Business\nemail: avni.khan@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1977-11-16\ndate_of_joining:
# 2022-05-08\nmanager_id: FINEMP1002\nsalary: 1875290.4\nleave_balance: 17\nleaves_taken: 10\nattendance_pct:
# 91.5\nperformance_rating: 4\nlast_review_date: 2024-07-05'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 37},
#         page_content='employee_id: FINEMP1037\nfull_name: Vihaan Garg\nrole: Sales Manager\ndepartment:
# Sales\nemail: vihaan.garg@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1986-08-12\ndate_of_joining:
# 2023-02-05\nmanager_id: FINEMP1001\nsalary: 403990.23\nleave_balance: 19\nleaves_taken: 19\nattendance_pct:
# 99.74\nperformance_rating: 5\nlast_review_date: 2024-01-10'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 38},
#         page_content='employee_id: FINEMP1038\nfull_name: Diya Bhat\nrole: Security Engineer\ndepartment:
# Technology\nemail: diya.bhat@fintechco.com\nlocation: Pune\ndate_of_birth: 1994-01-23\ndate_of_joining:
# 2018-02-22\nmanager_id: FINEMP1007\nsalary: 1152589.39\nleave_balance: 4\nleaves_taken: 3\nattendance_pct:
# 92.5\nperformance_rating: 4\nlast_review_date: 2024-05-13'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 39},
#         page_content='employee_id: FINEMP1039\nfull_name: Sai Desai\nrole: DevOps Engineer\ndepartment:
# Technology\nemail: sai.desai@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1994-08-25\ndate_of_joining:
# 2021-08-28\nmanager_id: FINEMP1005\nsalary: 1246312.4\nleave_balance: 10\nleaves_taken: 3\nattendance_pct:
# 90.36\nperformance_rating: 5\nlast_review_date: 2024-10-24'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 40},
#         page_content='employee_id: FINEMP1040\nfull_name: Vihaan Reddy\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: vihaan.reddy@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1985-02-08\ndate_of_joining:
# 2021-04-23\nmanager_id: FINEMP1006\nsalary: 1039818.46\nleave_balance: 8\nleaves_taken: 7\nattendance_pct:
# 94.28\nperformance_rating: 3\nlast_review_date: 2024-03-24'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 41},
#         page_content='employee_id: FINEMP1041\nfull_name: Shaurya Joshi\nrole: Relationship Manager\ndepartment:
# Sales\nemail: shaurya.joshi@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1995-01-15\ndate_of_joining:
# 2023-06-15\nmanager_id: FINEMP1000\nsalary: 1703490.23\nleave_balance: 7\nleaves_taken: 6\nattendance_pct:
# 90.84\nperformance_rating: 1\nlast_review_date: 2024-07-30'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 42},
#         page_content='employee_id: FINEMP1042\nfull_name: Vihaan Desai\nrole: Customer Support\ndepartment:
# Operations\nemail: vihaan.desai@fintechco.com\nlocation: Pune\ndate_of_birth: 1992-12-01\ndate_of_joining:
# 2024-03-28\nmanager_id: FINEMP1007\nsalary: 1785167.47\nleave_balance: 16\nleaves_taken: 1\nattendance_pct:
# 89.15\nperformance_rating: 4\nlast_review_date: 2025-04-28'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 43},
#         page_content='employee_id: FINEMP1043\nfull_name: Aadhya Singh\nrole: Sales Manager\ndepartment:
# Sales\nemail: aadhya.singh@fintechco.com\nlocation: Pune\ndate_of_birth: 1984-05-24\ndate_of_joining:
# 2024-06-02\nmanager_id: FINEMP1000\nsalary: 849227.01\nleave_balance: 17\nleaves_taken: 14\nattendance_pct:
# 91.97\nperformance_rating: 4\nlast_review_date: 2024-02-16'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 44},
#         page_content='employee_id: FINEMP1044\nfull_name: Isha Desai\nrole: Software Engineer\ndepartment:
# Technology\nemail: isha.desai@fintechco.com\nlocation: Chennai\ndate_of_birth: 1988-12-22\ndate_of_joining:
# 2021-12-03\nmanager_id: FINEMP1008\nsalary: 667541.44\nleave_balance: 9\nleaves_taken: 1\nattendance_pct:
# 88.61\nperformance_rating: 5\nlast_review_date: 2024-09-13'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 45},
#         page_content='employee_id: FINEMP1045\nfull_name: Ananya Banerjee\nrole: Data Analyst\ndepartment:
# Data\nemail: ananya.banerjee@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1996-04-07\ndate_of_joining:
# 2023-10-29\nmanager_id: FINEMP1000\nsalary: 911824.83\nleave_balance: 14\nleaves_taken: 4\nattendance_pct:
# 99.1\nperformance_rating: 4\nlast_review_date: 2025-02-05'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 46},
#         page_content='employee_id: FINEMP1046\nfull_name: Shaurya Joshi\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: shaurya.joshi@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1987-12-21\ndate_of_joining:
# 2018-11-03\nmanager_id: FINEMP1008\nsalary: 865704.81\nleave_balance: 19\nleaves_taken: 17\nattendance_pct:
# 94.1\nperformance_rating: 1\nlast_review_date: 2024-04-13'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 47},
#         page_content='employee_id: FINEMP1047\nfull_name: Ishaan Singh\nrole: Business Analyst\ndepartment:
# Business\nemail: ishaan.singh@fintechco.com\nlocation: Chennai\ndate_of_birth: 1981-11-25\ndate_of_joining:
# 2018-11-25\nmanager_id: FINEMP1007\nsalary: 1858162.08\nleave_balance: 24\nleaves_taken: 24\nattendance_pct:
# 86.19\nperformance_rating: 5\nlast_review_date: 2025-03-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 48},
#         page_content='employee_id: FINEMP1048\nfull_name: Isha Singh\nrole: Financial Analyst\ndepartment:
# Finance\nemail: isha.singh@fintechco.com\nlocation: Delhi\ndate_of_birth: 1994-10-22\ndate_of_joining:
# 2023-03-26\nmanager_id: FINEMP1008\nsalary: 1386670.96\nleave_balance: 14\nleaves_taken: 7\nattendance_pct:
# 98.85\nperformance_rating: 3\nlast_review_date: 2024-07-31'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 49},
#         page_content='employee_id: FINEMP1049\nfull_name: Arjun Garg\nrole: Product Manager\ndepartment:
# Product\nemail: arjun.garg@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1977-09-17\ndate_of_joining:
# 2024-05-08\nmanager_id: FINEMP1005\nsalary: 1447037.81\nleave_balance: 13\nleaves_taken: 4\nattendance_pct:
# 85.89\nperformance_rating: 5\nlast_review_date: 2024-02-01'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 50},
#         page_content='employee_id: FINEMP1050\nfull_name: Myra Gupta\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: myra.gupta@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1982-10-12\ndate_of_joining:
# 2021-02-01\nmanager_id: FINEMP1008\nsalary: 865633.34\nleave_balance: 25\nleaves_taken: 6\nattendance_pct:
# 97.9\nperformance_rating: 1\nlast_review_date: 2024-05-17'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 51},
#         page_content='employee_id: FINEMP1051\nfull_name: Reyansh Saxena\nrole: Security Engineer\ndepartment:
# Technology\nemail: reyansh.saxena@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1992-10-09\ndate_of_joining:
# 2023-09-01\nmanager_id: FINEMP1000\nsalary: 1064443.02\nleave_balance: 26\nleaves_taken: 2\nattendance_pct:
# 80.35\nperformance_rating: 4\nlast_review_date: 2025-04-15'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 52},
#         page_content='employee_id: FINEMP1052\nfull_name: Ishaan Singh\nrole: Relationship Manager\ndepartment:
# Sales\nemail: ishaan.singh@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1998-05-14\ndate_of_joining:
# 2018-07-09\nmanager_id: FINEMP1000\nsalary: 1673343.38\nleave_balance: 0\nleaves_taken: 0\nattendance_pct:
# 80.95\nperformance_rating: 4\nlast_review_date: 2024-06-08'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 53},
#         page_content='employee_id: FINEMP1053\nfull_name: Isha Sharma\nrole: Customer Support\ndepartment:
# Operations\nemail: isha.sharma@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1991-12-07\ndate_of_joining:
# 2020-11-08\nmanager_id: FINEMP1002\nsalary: 1502270.01\nleave_balance: 7\nleaves_taken: 7\nattendance_pct:
# 91.65\nperformance_rating: 5\nlast_review_date: 2024-05-12'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 54},
#         page_content='employee_id: FINEMP1054\nfull_name: Ishaan Singh\nrole: Data Scientist\ndepartment:
# Data\nemail: ishaan.singh@fintechco.com\nlocation: Delhi\ndate_of_birth: 1975-05-28\ndate_of_joining:
# 2019-10-12\nmanager_id: FINEMP1004\nsalary: 1675521.46\nleave_balance: 21\nleaves_taken: 4\nattendance_pct:
# 84.17\nperformance_rating: 1\nlast_review_date: 2024-06-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 55},
#         page_content='employee_id: FINEMP1055\nfull_name: Aditya Saxena\nrole: HR Manager\ndepartment: HR\nemail:
# aditya.saxena@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1981-08-27\ndate_of_joining:
# 2024-09-30\nmanager_id: FINEMP1009\nsalary: 745459.27\nleave_balance: 11\nleaves_taken: 2\nattendance_pct:
# 91.63\nperformance_rating: 1\nlast_review_date: 2024-03-07'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 56},
#         page_content='employee_id: FINEMP1056\nfull_name: Saanvi Bhat\nrole: UX Designer\ndepartment:
# Design\nemail: saanvi.bhat@fintechco.com\nlocation: Delhi\ndate_of_birth: 1980-10-25\ndate_of_joining:
# 2018-08-15\nmanager_id: FINEMP1004\nsalary: 685364.51\nleave_balance: 2\nleaves_taken: 1\nattendance_pct:
# 99.67\nperformance_rating: 2\nlast_review_date: 2024-06-24'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 57},
#         page_content='employee_id: FINEMP1057\nfull_name: Aditya Kapoor\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: aditya.kapoor@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1979-10-19\ndate_of_joining:
# 2022-04-22\nmanager_id: FINEMP1006\nsalary: 1641119.13\nleave_balance: 10\nleaves_taken: 1\nattendance_pct:
# 92.5\nperformance_rating: 2\nlast_review_date: 2024-06-07'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 58},
#         page_content='employee_id: FINEMP1058\nfull_name: Avni Chopra\nrole: Financial Analyst\ndepartment:
# Finance\nemail: avni.chopra@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1990-07-25\ndate_of_joining:
# 2019-09-03\nmanager_id: FINEMP1006\nsalary: 1098952.83\nleave_balance: 8\nleaves_taken: 3\nattendance_pct:
# 96.31\nperformance_rating: 5\nlast_review_date: 2025-01-31'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 59},
#         page_content='employee_id: FINEMP1059\nfull_name: Saanvi Malhotra\nrole: Customer Support\ndepartment:
# Operations\nemail: saanvi.malhotra@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1995-05-31\ndate_of_joining:
# 2018-08-30\nmanager_id: FINEMP1006\nsalary: 1430154.39\nleave_balance: 12\nleaves_taken: 12\nattendance_pct:
# 93.02\nperformance_rating: 2\nlast_review_date: 2025-04-25'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 60},
#         page_content='employee_id: FINEMP1060\nfull_name: Arjun Mehta\nrole: Sales Manager\ndepartment:
# Sales\nemail: arjun.mehta@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1985-08-27\ndate_of_joining:
# 2020-11-05\nmanager_id: FINEMP1007\nsalary: 1258070.34\nleave_balance: 6\nleaves_taken: 0\nattendance_pct:
# 98.75\nperformance_rating: 4\nlast_review_date: 2024-09-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 61},
#         page_content='employee_id: FINEMP1061\nfull_name: Vivaan Chowdhury\nrole: Blockchain Developer\ndepartment:
# Technology\nemail: vivaan.chowdhury@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1982-09-21\ndate_of_joining:
# 2020-03-01\nmanager_id: FINEMP1008\nsalary: 1349620.28\nleave_balance: 9\nleaves_taken: 0\nattendance_pct:
# 81.37\nperformance_rating: 3\nlast_review_date: 2024-01-19'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 62},
#         page_content='employee_id: FINEMP1062\nfull_name: Ananya Iyer\nrole: Product Manager\ndepartment:
# Product\nemail: ananya.iyer@fintechco.com\nlocation: Chennai\ndate_of_birth: 1982-07-13\ndate_of_joining:
# 2019-08-23\nmanager_id: FINEMP1007\nsalary: 1641718.19\nleave_balance: 17\nleaves_taken: 7\nattendance_pct:
# 96.07\nperformance_rating: 1\nlast_review_date: 2025-03-09'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 63},
#         page_content='employee_id: FINEMP1063\nfull_name: Aadhya Kapoor\nrole: Risk Analyst\ndepartment:
# Risk\nemail: aadhya.kapoor@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1991-07-10\ndate_of_joining:
# 2021-10-27\nmanager_id: FINEMP1004\nsalary: 1833641.2\nleave_balance: 8\nleaves_taken: 1\nattendance_pct:
# 85.81\nperformance_rating: 2\nlast_review_date: 2024-06-29'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 64},
#         page_content='employee_id: FINEMP1064\nfull_name: Saanvi Nair\nrole: Risk Analyst\ndepartment: Risk\nemail:
# saanvi.nair@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1982-09-11\ndate_of_joining: 2021-05-12\nmanager_id:
# FINEMP1004\nsalary: 1809813.11\nleave_balance: 0\nleaves_taken: 0\nattendance_pct: 83.64\nperformance_rating:
# 2\nlast_review_date: 2024-05-17'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 65},
#         page_content='employee_id: FINEMP1065\nfull_name: Myra Garg\nrole: Blockchain Developer\ndepartment:
# Technology\nemail: myra.garg@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1989-05-09\ndate_of_joining:
# 2019-03-28\nmanager_id: FINEMP1004\nsalary: 1947873.28\nleave_balance: 6\nleaves_taken: 2\nattendance_pct:
# 81.24\nperformance_rating: 2\nlast_review_date: 2024-10-03'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 66},
#         page_content='employee_id: FINEMP1066\nfull_name: Diya Iyer\nrole: Sales Manager\ndepartment: Sales\nemail:
# diya.iyer@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1977-05-24\ndate_of_joining: 2020-12-19\nmanager_id:
# FINEMP1008\nsalary: 1333935.56\nleave_balance: 24\nleaves_taken: 10\nattendance_pct: 91.78\nperformance_rating:
# 1\nlast_review_date: 2025-01-09'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 67},
#         page_content='employee_id: FINEMP1067\nfull_name: Shaurya Chopra\nrole: Compliance Officer\ndepartment:
# Compliance\nemail: shaurya.chopra@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1998-03-26\ndate_of_joining:
# 2021-10-06\nmanager_id: FINEMP1001\nsalary: 368244.88\nleave_balance: 0\nleaves_taken: 0\nattendance_pct:
# 80.02\nperformance_rating: 3\nlast_review_date: 2024-05-01'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 68},
#         page_content='employee_id: FINEMP1068\nfull_name: Shaurya Singh\nrole: Data Scientist\ndepartment:
# Data\nemail: shaurya.singh@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1979-05-02\ndate_of_joining:
# 2024-02-23\nmanager_id: FINEMP1002\nsalary: 1803057.99\nleave_balance: 6\nleaves_taken: 0\nattendance_pct:
# 81.1\nperformance_rating: 3\nlast_review_date: 2024-11-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 69},
#         page_content='employee_id: FINEMP1069\nfull_name: Vivaan Saxena\nrole: Risk Analyst\ndepartment:
# Risk\nemail: vivaan.saxena@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1996-07-25\ndate_of_joining:
# 2018-04-21\nmanager_id: FINEMP1003\nsalary: 1596298.88\nleave_balance: 21\nleaves_taken: 12\nattendance_pct:
# 96.61\nperformance_rating: 4\nlast_review_date: 2024-09-28'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 70},
#         page_content='employee_id: FINEMP1070\nfull_name: Saanvi Banerjee\nrole: Credit Officer\ndepartment:
# Finance\nemail: saanvi.banerjee@fintechco.com\nlocation: Pune\ndate_of_birth: 1978-10-20\ndate_of_joining:
# 2020-12-24\nmanager_id: FINEMP1000\nsalary: 1872784.84\nleave_balance: 17\nleaves_taken: 6\nattendance_pct:
# 95.36\nperformance_rating: 2\nlast_review_date: 2024-02-04'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 71},
#         page_content='employee_id: FINEMP1071\nfull_name: Vivaan Verma\nrole: Credit Officer\ndepartment:
# Finance\nemail: vivaan.verma@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1986-04-27\ndate_of_joining:
# 2019-03-21\nmanager_id: FINEMP1008\nsalary: 1643988.07\nleave_balance: 0\nleaves_taken: 0\nattendance_pct:
# 98.33\nperformance_rating: 2\nlast_review_date: 2024-10-15'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 72},
#         page_content='employee_id: FINEMP1072\nfull_name: Saanvi Gupta\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: saanvi.gupta@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1998-08-31\ndate_of_joining:
# 2019-11-08\nmanager_id: FINEMP1003\nsalary: 1333187.28\nleave_balance: 15\nleaves_taken: 1\nattendance_pct:
# 97.66\nperformance_rating: 3\nlast_review_date: 2024-07-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 73},
#         page_content='employee_id: FINEMP1073\nfull_name: Diya Nair\nrole: Relationship Manager\ndepartment:
# Sales\nemail: diya.nair@fintechco.com\nlocation: Delhi\ndate_of_birth: 1988-11-24\ndate_of_joining:
# 2024-08-22\nmanager_id: FINEMP1004\nsalary: 1416536.32\nleave_balance: 0\nleaves_taken: 0\nattendance_pct:
# 95.13\nperformance_rating: 5\nlast_review_date: 2025-01-29'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 74},
#         page_content='employee_id: FINEMP1074\nfull_name: Vihaan Chopra\nrole: Relationship Manager\ndepartment:
# Sales\nemail: vihaan.chopra@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1996-03-28\ndate_of_joining:
# 2024-09-10\nmanager_id: FINEMP1005\nsalary: 1938308.68\nleave_balance: 6\nleaves_taken: 5\nattendance_pct:
# 92.42\nperformance_rating: 3\nlast_review_date: 2025-04-12'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 75},
#         page_content='employee_id: FINEMP1075\nfull_name: Ananya Khan\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: ananya.khan@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1994-03-30\ndate_of_joining:
# 2019-05-14\nmanager_id: FINEMP1009\nsalary: 687174.91\nleave_balance: 6\nleaves_taken: 4\nattendance_pct:
# 87.01\nperformance_rating: 5\nlast_review_date: 2025-04-27'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 76},
#         page_content='employee_id: FINEMP1076\nfull_name: Avni Chowdhury\nrole: Credit Officer\ndepartment:
# Finance\nemail: avni.chowdhury@fintechco.com\nlocation: Delhi\ndate_of_birth: 1994-03-28\ndate_of_joining:
# 2022-01-25\nmanager_id: FINEMP1008\nsalary: 589221.29\nleave_balance: 27\nleaves_taken: 26\nattendance_pct:
# 88.76\nperformance_rating: 4\nlast_review_date: 2024-02-25'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 77},
#         page_content='employee_id: FINEMP1077\nfull_name: Krishna Nair\nrole: UX Designer\ndepartment:
# Design\nemail: krishna.nair@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1995-08-16\ndate_of_joining:
# 2019-12-07\nmanager_id: FINEMP1004\nsalary: 1477253.1\nleave_balance: 8\nleaves_taken: 5\nattendance_pct:
# 97.75\nperformance_rating: 1\nlast_review_date: 2024-08-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 78},
#         page_content='employee_id: FINEMP1078\nfull_name: Prisha Chopra\nrole: Data Analyst\ndepartment:
# Data\nemail: prisha.chopra@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1981-03-18\ndate_of_joining:
# 2023-08-01\nmanager_id: FINEMP1001\nsalary: 1438958.04\nleave_balance: 24\nleaves_taken: 1\nattendance_pct:
# 90.49\nperformance_rating: 2\nlast_review_date: 2024-02-28'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 79},
#         page_content='employee_id: FINEMP1079\nfull_name: Krishna Iyer\nrole: Financial Analyst\ndepartment:
# Finance\nemail: krishna.iyer@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1984-02-29\ndate_of_joining:
# 2023-10-05\nmanager_id: FINEMP1000\nsalary: 1507078.74\nleave_balance: 20\nleaves_taken: 11\nattendance_pct:
# 87.41\nperformance_rating: 3\nlast_review_date: 2024-01-22'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 80},
#         page_content='employee_id: FINEMP1080\nfull_name: Avni Reddy\nrole: Data Analyst\ndepartment: Data\nemail:
# avni.reddy@fintechco.com\nlocation: Pune\ndate_of_birth: 1995-01-29\ndate_of_joining: 2021-02-24\nmanager_id:
# FINEMP1000\nsalary: 400948.72\nleave_balance: 14\nleaves_taken: 0\nattendance_pct: 81.49\nperformance_rating:
# 5\nlast_review_date: 2024-12-08'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 81},
#         page_content='employee_id: FINEMP1081\nfull_name: Sakshi Malhotra\nrole: Credit Officer\ndepartment:
# Finance\nemail: sakshi.malhotra@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1997-06-09\ndate_of_joining:
# 2019-06-09\nmanager_id: FINEMP1004\nsalary: 1113984.52\nleave_balance: 25\nleaves_taken: 18\nattendance_pct:
# 80.71\nperformance_rating: 3\nlast_review_date: 2024-07-26'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 82},
#         page_content='employee_id: FINEMP1082\nfull_name: Vihaan Chowdhury\nrole: Financial Analyst\ndepartment:
# Finance\nemail: vihaan.chowdhury@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1998-06-24\ndate_of_joining:
# 2018-07-22\nmanager_id: FINEMP1005\nsalary: 1036719.56\nleave_balance: 18\nleaves_taken: 7\nattendance_pct:
# 93.4\nperformance_rating: 2\nlast_review_date: 2024-01-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 83},
#         page_content='employee_id: FINEMP1083\nfull_name: Krishna Malhotra\nrole: Sales Manager\ndepartment:
# Sales\nemail: krishna.malhotra@fintechco.com\nlocation: Pune\ndate_of_birth: 1976-08-20\ndate_of_joining:
# 2022-12-26\nmanager_id: FINEMP1001\nsalary: 1413177.7\nleave_balance: 25\nleaves_taken: 21\nattendance_pct:
# 91.85\nperformance_rating: 1\nlast_review_date: 2024-01-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 84},
#         page_content='employee_id: FINEMP1084\nfull_name: Saanvi Chowdhury\nrole: Business Analyst\ndepartment:
# Business\nemail: saanvi.chowdhury@fintechco.com\nlocation: Pune\ndate_of_birth: 1976-03-24\ndate_of_joining:
# 2023-06-22\nmanager_id: FINEMP1004\nsalary: 1982774.95\nleave_balance: 5\nleaves_taken: 4\nattendance_pct:
# 99.17\nperformance_rating: 2\nlast_review_date: 2024-06-10'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 85},
#         page_content='employee_id: FINEMP1085\nfull_name: Aadhya Mehta\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: aadhya.mehta@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1983-12-03\ndate_of_joining:
# 2021-10-11\nmanager_id: FINEMP1000\nsalary: 1026240.03\nleave_balance: 6\nleaves_taken: 6\nattendance_pct:
# 92.28\nperformance_rating: 2\nlast_review_date: 2024-12-19'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 86},
#         page_content='employee_id: FINEMP1086\nfull_name: Diya Iyer\nrole: Data Analyst\ndepartment: Data\nemail:
# diya.iyer@fintechco.com\nlocation: Kolkata\ndate_of_birth: 1989-09-24\ndate_of_joining: 2018-11-28\nmanager_id:
# FINEMP1006\nsalary: 1950772.9\nleave_balance: 2\nleaves_taken: 2\nattendance_pct: 88.26\nperformance_rating:
# 5\nlast_review_date: 2024-03-21'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 87},
#         page_content='employee_id: FINEMP1087\nfull_name: Avni Nair\nrole: Relationship Manager\ndepartment:
# Sales\nemail: avni.nair@fintechco.com\nlocation: Chennai\ndate_of_birth: 1999-08-05\ndate_of_joining:
# 2021-10-06\nmanager_id: FINEMP1008\nsalary: 1333720.85\nleave_balance: 19\nleaves_taken: 3\nattendance_pct:
# 90.98\nperformance_rating: 2\nlast_review_date: 2024-05-16'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 88},
#         page_content='employee_id: FINEMP1088\nfull_name: Avni Chowdhury\nrole: Customer Support\ndepartment:
# Operations\nemail: avni.chowdhury@fintechco.com\nlocation: Delhi\ndate_of_birth: 1989-05-18\ndate_of_joining:
# 2020-11-25\nmanager_id: FINEMP1005\nsalary: 614347.62\nleave_balance: 15\nleaves_taken: 0\nattendance_pct:
# 98.8\nperformance_rating: 5\nlast_review_date: 2024-04-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 89},
#         page_content='employee_id: FINEMP1089\nfull_name: Aarav Joshi\nrole: Security Engineer\ndepartment:
# Technology\nemail: aarav.joshi@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1977-05-07\ndate_of_joining:
# 2021-03-01\nmanager_id: FINEMP1003\nsalary: 330010.27\nleave_balance: 4\nleaves_taken: 4\nattendance_pct:
# 82.24\nperformance_rating: 1\nlast_review_date: 2024-10-29'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 90},
#         page_content='employee_id: FINEMP1090\nfull_name: Arjun Chowdhury\nrole: Software Engineer\ndepartment:
# Technology\nemail: arjun.chowdhury@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1993-02-04\ndate_of_joining:
# 2022-07-30\nmanager_id: FINEMP1007\nsalary: 454938.59\nleave_balance: 23\nleaves_taken: 9\nattendance_pct:
# 91.15\nperformance_rating: 1\nlast_review_date: 2024-09-26'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 91},
#         page_content='employee_id: FINEMP1091\nfull_name: Diya Desai\nrole: Compliance Officer\ndepartment:
# Compliance\nemail: diya.desai@fintechco.com\nlocation: Chennai\ndate_of_birth: 1982-05-28\ndate_of_joining:
# 2022-03-23\nmanager_id: FINEMP1008\nsalary: 1262938.4\nleave_balance: 19\nleaves_taken: 3\nattendance_pct:
# 86.4\nperformance_rating: 1\nlast_review_date: 2024-08-30'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 92},
#         page_content='employee_id: FINEMP1092\nfull_name: Ananya Nair\nrole: HR Manager\ndepartment: HR\nemail:
# ananya.nair@fintechco.com\nlocation: Hyderabad\ndate_of_birth: 1997-11-12\ndate_of_joining: 2019-11-25\nmanager_id:
# FINEMP1003\nsalary: 512211.07\nleave_balance: 4\nleaves_taken: 4\nattendance_pct: 85.19\nperformance_rating:
# 3\nlast_review_date: 2024-05-18'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 93},
#         page_content='employee_id: FINEMP1093\nfull_name: Shaurya Sharma\nrole: Product Manager\ndepartment:
# Product\nemail: shaurya.sharma@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1976-10-18\ndate_of_joining:
# 2024-07-28\nmanager_id: FINEMP1002\nsalary: 1325752.2\nleave_balance: 12\nleaves_taken: 9\nattendance_pct:
# 93.73\nperformance_rating: 5\nlast_review_date: 2024-01-31'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 94},
#         page_content='employee_id: FINEMP1094\nfull_name: Aarav Kapoor\nrole: UX Designer\ndepartment:
# Design\nemail: aarav.kapoor@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1994-12-04\ndate_of_joining:
# 2023-06-29\nmanager_id: FINEMP1007\nsalary: 1373465.39\nleave_balance: 24\nleaves_taken: 2\nattendance_pct:
# 91.59\nperformance_rating: 2\nlast_review_date: 2024-10-23'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 95},
#         page_content='employee_id: FINEMP1095\nfull_name: Ananya Khan\nrole: QA Engineer\ndepartment: Quality
# Assurance\nemail: ananya.khan@fintechco.com\nlocation: Delhi\ndate_of_birth: 1997-04-09\ndate_of_joining:
# 2021-03-12\nmanager_id: FINEMP1008\nsalary: 305337.03\nleave_balance: 18\nleaves_taken: 4\nattendance_pct:
# 88.06\nperformance_rating: 5\nlast_review_date: 2024-02-15'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 96},
#         page_content='employee_id: FINEMP1096\nfull_name: Krishna Bhat\nrole: Credit Officer\ndepartment:
# Finance\nemail: krishna.bhat@fintechco.com\nlocation: Delhi\ndate_of_birth: 1983-07-25\ndate_of_joining:
# 2022-03-25\nmanager_id: FINEMP1003\nsalary: 807527.48\nleave_balance: 8\nleaves_taken: 6\nattendance_pct:
# 97.67\nperformance_rating: 3\nlast_review_date: 2024-01-04'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 97},
#         page_content='employee_id: FINEMP1097\nfull_name: Sakshi Kapoor\nrole: Marketing Manager\ndepartment:
# Marketing\nemail: sakshi.kapoor@fintechco.com\nlocation: Bengaluru\ndate_of_birth: 1995-09-14\ndate_of_joining:
# 2018-02-10\nmanager_id: FINEMP1000\nsalary: 1468652.84\nleave_balance: 18\nleaves_taken: 14\nattendance_pct:
# 94.91\nperformance_rating: 2\nlast_review_date: 2024-05-14'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 98},
#         page_content='employee_id: FINEMP1098\nfull_name: Arjun Patel\nrole: Risk Analyst\ndepartment: Risk\nemail:
# arjun.patel@fintechco.com\nlocation: Jaipur\ndate_of_birth: 1994-01-29\ndate_of_joining: 2018-11-26\nmanager_id:
# FINEMP1004\nsalary: 1521060.31\nleave_balance: 19\nleaves_taken: 9\nattendance_pct: 92.26\nperformance_rating:
# 4\nlast_review_date: 2024-08-06'
#     ),
#     Document(
#         metadata={'source': '../../data/hr/hr_data.csv', 'row': 99},
#         page_content='employee_id: FINEMP1099\nfull_name: Shaurya Chowdhury\nrole: DevOps Engineer\ndepartment:
# Technology\nemail: shaurya.chowdhury@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1996-11-20\ndate_of_joining:
# 2020-07-28\nmanager_id: FINEMP1008\nsalary: 586137.55\nleave_balance: 12\nleaves_taken: 3\nattendance_pct:
# 95.52\nperformance_rating: 3\nlast_review_date: 2024-11-09'
#     )
# ]

# %%
db=Chroma.from_documents(documents=data,embedding=model,persist_directory="hr_csv")

# %%
db.similarity_search("Aadhya Patel and Sales Manager")
# Out:
# [Document(id='36b993ce-0356-4d2b-99c9-3044b3d5c797', metadata={'source': '../../data/hr/hr_data.csv', 'row': 0}, page_content='employee_id: FINEMP1000\nfull_name: Aadhya Patel\nrole: Sales Manager\ndepartment: Sales\nemail: aadhya.patel@fintechco.com\nlocation: Ahmedabad\ndate_of_birth: 1991-04-03\ndate_of_joining: 2018-11-20\nmanager_id: FINEMP1006\nsalary: 1332478.37\nleave_balance: 22\nleaves_taken: 11\nattendance_pct: 99.31\nperformance_rating: 3\nlast_review_date: 2024-05-21'),
#  Document(id='700590a7-04e2-4918-ae99-493abeaa7939', metadata={'source': '../../data/hr/hr_data.csv', 'row': 43}, page_content='employee_id: FINEMP1043\nfull_name: Aadhya Singh\nrole: Sales Manager\ndepartment: Sales\nemail: aadhya.singh@fintechco.com\nlocation: Pune\ndate_of_birth: 1984-05-24\ndate_of_joining: 2024-06-02\nmanager_id: FINEMP1000\nsalary: 849227.01\nleave_balance: 17\nleaves_taken: 14\nattendance_pct: 91.97\nperformance_rating: 4\nlast_review_date: 2024-02-16'),
#  Document(id='6894c7ee-f46f-4873-b52a-e0dcd9a176ab', metadata={'row': 4, 'source': '../../data/hr/hr_data.csv'}, page_content='employee_id: FINEMP1004\nfull_name: Aadhya Saxena\nrole: Marketing Manager\ndepartment: Marketing\nemail: aadhya.saxena@fintechco.com\nlocation: Lucknow\ndate_of_birth: 1986-03-31\ndate_of_joining: 2022-12-20\nmanager_id: FINEMP1008\nsalary: 1922205.04\nleave_balance: 21\nleaves_taken: 10\nattendance_pct: 86.03\nperformance_rating: 3\nlast_review_date: 2024-01-12'),
#  Document(id='87100b29-6854-46a4-ba3b-1cb94c6f4178', metadata={'row': 8, 'source': '../../data/hr/hr_data.csv'}, page_content='employee_id: FINEMP1008\nfull_name: Aadhya Chowdhury\nrole: Customer Support\ndepartment: Operations\nemail: aadhya.chowdhury@fintechco.com\nlocation: Mumbai\ndate_of_birth: 1977-06-18\ndate_of_joining: 2019-02-12\nmanager_id: FINEMP1007\nsalary: 370315.98\nleave_balance: 7\nleaves_taken: 5\nattendance_pct: 96.92\nperformance_rating: 5\nlast_review_date: 2024-08-07')]
